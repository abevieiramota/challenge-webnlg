# %%
from webnlg_corpus import webnlg

corpus = webnlg.load('webnlg_challenge_2017')

train_dev = corpus.subset(datasets=['train', 'dev'])

# %%
train_dev.mdf.subject.sample(n=10, random_state=100)
# Out:
# 20553                                        United_States
# 5611                                                 Bakso
# 6597     Abhandlungen_aus_dem_Mathematischen_Seminar_de...
# 5834                                           Ayam_penyet
# 7865                                   Akita_Museum_of_Art
# 7465                                            Elliot_See
# 1446                                               Bionico
# 20653                                        United_States
# 13581                                        Bandeja_paisa
# 3455                                     Bianca_Castafiore
# Name: subject, dtype: object

# %% [markdown]
# So, there are subjects(probably predicates and objects too) that have *underlines* and *parenthesis*.

# %% [markdown]
# ## How many has underlines or parenthesis?

# %%
has_underline_parenthesis = train_dev.mdf.subject.str.match(r'.*[_\(\)].*')

train_dev.mdf.shape, has_underline_parenthesis.sum()
# Out:
# ((23021, 7), 17505)

# %%
# some samples
train_dev.mdf[has_underline_parenthesis].sample(n=10, random_state=200)
# Out:
#               category dataset                           idx  \
# 3022          Building   train         train_Building_1_Id87
# 8163   ComicsCharacter   train  train_ComicsCharacter_3_Id12
# 10180      WrittenWork   train      train_WrittenWork_3_Id36
# 184         SportsTeam     dev         dev_SportsTeam_1_Id26
# 18380             Food   train             train_Food_5_Id23
# 172         SportsTeam     dev         dev_SportsTeam_1_Id14
# 22142        Astronaut   train        train_Astronaut_7_Id45
# 2168        SportsTeam     dev          dev_SportsTeam_5_Id4
# 1740           Airport     dev            dev_Airport_5_Id10
# 17446         Building   train          train_Building_5_Id3
#
#                                           object             predicate  \
# 3022                                   Sri_Lanka              location
# 8163                               Walt_Simonson               creator
# 10180                    "ACM Trans. Inf. Syst."          abbreviation
# 184                                   AZ_Alkmaar                  club
# 18380   "Tomatoes, red chili, garlic, olive oil"       mainIngredients
# 172                         "Joden , Godenzonen"              nickname
# 22142                                  Apollo_11  was a crew member of
# 2168   Estádio_Municipal_Coaracy_da_Mata_Fonseca                ground
# 1740            United_States_invasion_of_Panama               battles
# 17446         "120 million (Australian dollars)"                  cost
#
#                                        subject  \
# 3022                              Adisham_Hall
# 8163                   Auron_(comicsCharacter)
# 10180  ACM_Transactions_on_Information_Systems
# 184                          John_van_den_Brom
# 18380                         Arrabbiata_sauce
# 172                        AFC_Ajax_(amateurs)
# 22142                              Buzz_Aldrin
# 2168         Agremiação_Sportiva_Arapiraquense
# 1740                   United_States_Air_Force
# 17446                   108_St_Georges_Terrace
#
#                                                     text
# 3022                 Adisham_Hall | location | Sri_Lanka
# 8163   Auron_(comicsCharacter) | creator | Walt_Simonson
# 10180  ACM_Transactions_on_Information_Systems | abbr...
# 184                John_van_den_Brom | club | AZ_Alkmaar
# 18380  Arrabbiata_sauce | mainIngredients | "Tomatoes...
# 172    AFC_Ajax_(amateurs) | nickname | "Joden , Gode...
# 22142     Buzz_Aldrin | was a crew member of | Apollo_11
# 2168   Agremiação_Sportiva_Arapiraquense | ground | E...
# 1740   United_States_Air_Force | battles | United_Sta...
# 17446  108_St_Georges_Terrace | cost | "120 million (...

# %%
# and without parenthesis or underlines
train_dev.mdf[~has_underline_parenthesis].sample(n=10, random_state=123)
# Out:
#               category dataset                           idx  \
# 12948             Food   train              train_Food_4_Id3
# 20118       University   train       train_University_5_Id44
# 651           Building     dev            dev_Building_3_Id9
# 3426   ComicsCharacter   train  train_ComicsCharacter_1_Id12
# 18323             Food   train             train_Food_5_Id12
# 18734             Food   train             train_Food_5_Id94
# 13850             Food   train            train_Food_4_Id229
# 21743       University   train       train_University_6_Id48
# 406               Food     dev               dev_Food_2_Id31
# 1019       WrittenWork     dev        dev_WrittenWork_3_Id24
#
#                         object             predicate    subject  \
# 12948                    Water            ingredient  Ajoblanco
# 20118                Telangana  has to its northeast  Karnataka
# 651        Republic_of_Ireland               country     Dublin
# 3426                "Aurakles"       alternativeName   Aurakles
# 18323                Indonesia               country  Arem-arem
# 18734             Manuel_Valls            leaderName     France
# 13850  Sandesh_(confectionery)         dishVariation    Dessert
# 21743           Klaus_Iohannis            leaderName    Romania
# 406               Sweet_potato       mainIngredients   Binignit
# 1019                  45644811           OCLC_number      Aenir
#
#                                                     text
# 12948                     Ajoblanco | ingredient | Water
# 20118       Karnataka | has to its northeast | Telangana
# 651               Dublin | country | Republic_of_Ireland
# 3426             Aurakles | alternativeName | "Aurakles"
# 18323                    Arem-arem | country | Indonesia
# 18734                 France | leaderName | Manuel_Valls
# 13850  Dessert | dishVariation | Sandesh_(confectionery)
# 21743              Romania | leaderName | Klaus_Iohannis
# 406            Binignit | mainIngredients | Sweet_potato
# 1019                      Aenir | OCLC_number | 45644811

# %% [markdown]
# ## How underlines are lexicalized?

# %%
train_dev.sample(idx='train_University_6_Id48')
# Out:
# Triple info: Category=University eid=Id48 idx=train_University_6_Id48
#
# 	Modified Triples:
#
# Romania | ethnicGroup | Germans_of_Romania
# Alba_Iulia | isPartOf | Alba_County
# Romania | leaderName | Klaus_Iohannis
# Romania | capital | Bucharest
# 1_Decembrie_1918_University | city | Alba_Iulia
# 1_Decembrie_1918_University | country | Romania
#
#
# 	Lexicalizations:
#
# The 1 Decembrie 1918 University is located in Alba Iulia, Alba County, Romania. Romania's capital is Bucharest, its leader is Klaus Iohannis and its ethnic group is Germans of Romania.
#
#
# The country of Romania is lead by Klaus Iohannis and the capital city is Bucharest. One of the ethnic groups in the country are the Germans of Romania. The country is the location of the 1 Decembrie 1918 University in Alba Iulia, Alba County.
#
#
# Romania is governed by Klaus Iohannis and it's capital city is Bucharest. It is known for being home to the ethnic group the Germans of Romania and the 1 Decembrie 1918 University which is located in Alba Iulia in the Alba county.

# %% [markdown]
# ### Well, underline translates to a space?

# %%
train_dev.mdf.subject.str.translate('_'.maketrans({'_': ' '})).sample(n=10, random_state=200)
# Out:
# 14814                         John van den Brom
# 5983                                A.C. Cesena
# 5443                                 Asam pedas
# 8786                                      Bakso
# 21626           Acharya Institute of Technology
# 5834                                Ayam penyet
# 8165                                        BBC
# 3585                             Bacon sandwich
# 3580                             Bacon sandwich
# 19954    Accademia di Architettura di Mendrisio
# Name: subject, dtype: object

# %% [markdown]
# Looks fine

# %% [markdown]
# ## How parenthesis are lexicalized?

# %%
sample = train_dev.mdf[train_dev.mdf.subject.str.contains('\(')][['subject', 'object']].copy()
sample['subject_processed'] = sample.subject\
    .str.replace('(.*?)\((.*?)\)', '\g<2> \g<1>')\
    .str.replace('_', ' ')\
    .str.replace('([a-z])([A-Z])', '\g<1> \g<2>')\
    .str.strip('" ')

sample['object_processed'] = sample.object\
    .str.replace('(.*?)\((.*?)\)', '\g<2> \g<1>')\
    .str.replace('_', ' ')\
    .str.replace('([a-z])([A-Z])', '\g<1> \g<2>')\
    .str.strip('" ')

sample.tail()
# Out:
#                         subject           object       subject_processed  \
# 22631  Atatürk_Monument_(İzmir)  Pietro_Canonica  İzmir Atatürk Monument
# 22634  Atatürk_Monument_(İzmir)     "1932-07-27"  İzmir Atatürk Monument
# 22635  Atatürk_Monument_(İzmir)           Turkey  İzmir Atatürk Monument
# 22640  Atatürk_Monument_(İzmir)         "Bronze"  İzmir Atatürk Monument
# 22642  Atatürk_Monument_(İzmir)           Turkey  İzmir Atatürk Monument
#
#       object_processed
# 22631  Pietro Canonica
# 22634       1932-07-27
# 22635           Turkey
# 22640           Bronze
# 22642           Turkey
